# %% [markdown]
# <a href="https://colab.research.google.com/github/cmp79-pennstate/SRA-268/blob/master/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Graph Types**

# %% [markdown]
# Creator
#
#
#
# * Carly Palermo

# %% [markdown]
# ##**Deviation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**
#
# This graph is showing us the deviation of the winning points during each season of each year. In order to create this graph, I found the average and made it so that the winning points were split to be above average and below average. I utilized color to further differentiate between points above and below average. For above average, I chose to use blue. For below average, I chose to use red because this color usually indicates a negative/below a certain value. Lastly, I chose to use a bar graph to represent deviation because I believe this is the best way to indicate a clear picture of deviation.

# %% [markdown]
# ##**Correlation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**
#
# This correlation graph shown above represents the change in both winning and losing points for a duration of years. For this graph, I chose to use winning points and year of season as my variables to test. I used two different colors to show winning and losing points. This makes it easy to differentiate between the two, while also being visually pleasing. The losing points are colored blue and the winning points are colored orange. This graph creates a clear image of how both the winning points and losing points relate to one another from the years 1985 to 2017.

# %% [markdown]
# ##**Ranking**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**
#
# The graph shown above ranks the winning points in order from the least amount of winning points to the highest amount of winning points. I chose to rank the points based on the winning seasons from the years 1985 to 2017. For the ranking graph, I chose to use one color for the entirety of the graph in order to create a clear picture for the viewer and to make it visually pleasing. I chose to use a bar graph because I felt that it was the best graph to use to clealry represent a trend. Lastly, I separated each bar so that it was easy to see which bar pertained to what year.

# %% [markdown]
# ##**Distribution**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**
#
# This graph shows how the winning points have been distributed. I chose to make this graph one solid color so that it was easy to comprehend and would not confuse the viewer. I chose to use a histogram to represent the distribution of the data because I felt like it vividly shows how the winning points are spread. Also, by using the histogram I was able to come to the conclusion that the distribution of winning points is skewed to the right. I found that 75 points were also the most frequently amount of points made and that 125 points were scored the least.

# %% [markdown]
# ##**Change Over Time**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**
#
# This graph is a correlation graph, but is comparing two variables. The variables I chose were the year of season and winning/losing points. For this graph, I chose to use blue and orange as the colors to represent winning and losing points. Orange portrays the winning points and blue depicts the losing points. This graph shows the relationship between both winning and losing points over the span of 32 years. The correlation pictured above is how I imagined it would look. I expected winning points to be above losing points. However, I found it interesting that they both followed an almost identical pattern.

# %% [markdown]
# ##**Magnitude**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**
#
# The graph shown above represents the magnitude of winning points for each season of each year from 1985 to 2017. I chose to use a bar graph to represent the magnitude because I thought it created a clear picture of the magnitude of winning points per year. I separated the bars in the bar graph to make it easy on the eyes of the viewer. I also used various shades of blue as my color scheme. The darker the shade of blue, the higher the magnitude of winning points scored. Therefore, the lighter the shade of blue, the smaller the magnitude.

# %% [markdown]
# ##**Part-to-Whole**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is this telling us?**
#
# Pictured above is a part-to-whole graph. I chose to use a pie chart to represent the data. I chose to depict the days that the winning points exceeded 25,0000. The days that this occurred are: Thursday, Friday, Saturday, and Sunday. I was surprised to see that both Thursday and Friday both shared an almost identical percentage for winning points. I was also shocked that a greater amount of winning points occurred on Saturday rather than Sunday. I believe this graph is fairly easy to read. I chose to use this data because other datasets I chose contained many variables, which made it very colorful and not very pleasing in a visual sense.
